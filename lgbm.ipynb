# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier, StackingClassifier, RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import pickle
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
# setting Jedha color palette as default
pio.templates["jedha"] = go.layout.Template(
    layout_colorway=["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]
)
pio.templates.default = "jedha"
pio.renderers.default = "vscode" # to be replaced by "iframe" if working on JULIE
from IPython.display import display

# %%
data = pd.read_csv('data/conversion_data_train.csv')
print('Set with labels (our train+test) :', data.shape)
# Out:
# Set with labels (our train+test) : (284580, 6)

# %% [markdown]
# ### Train and Test sets for models

# %%
target_variable = 'converted'

X = data.drop(target_variable, axis=1)
Y = data.loc[:, target_variable]

print('Explanatory variables : ', X.columns)
print('Target variable :', target_variable)
print()
# Out:
# Explanatory variables :  Index(['country', 'age', 'new_user', 'source', 'total_pages_visited'], dtype='object')
# Target variable : converted

# %%
# Train set & Test set 
print("Dividing into train and test sets...")
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0, stratify=Y)
print("...Done.")
print()
# Out:
# Dividing into train and test sets...
# ...Done.

# %% [markdown]
# ## Preprocessing

# %%
numeric_features = ['age', 'total_pages_visited']
categorical_features = ['new_user', 'country', 'source']

print('Found numeric features ', numeric_features)
print('Found categorical features ', categorical_features)
# Out:
# Found numeric features  ['age', 'total_pages_visited']
# Found categorical features  ['new_user', 'country', 'source']

# %%
# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', KNNImputer()), 
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
categorical_transformer = Pipeline(
    steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')), # missing values will be replaced by most frequent value
    ('encoder', OneHotEncoder(drop='first')) # first column will be dropped to avoid creating correlations between features
    ])

# Use ColumnTransformer to make a preprocessor object that describes all the treatments to be done
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# %%
# Preprocessings on train set
print("Performing preprocessings on train set...")
print(X_train.head())
X_train = preprocessor.fit_transform(X_train)
print('...Done.')
print(X_train[0:5]) 
print()

# Preprocessings on test set
print("Performing preprocessings on test set...")
print(X_test.head()) 
X_test = preprocessor.transform(X_test) # Don't fit again !! 
print('...Done.')
print(X_test[0:5,:])
# Out:
# Performing preprocessings on train set...
#        country  age  new_user  source  total_pages_visited
# 137434   China   19         1     Seo                    1
# 112323      US   33         1  Direct                    5
# 143261      US   51         1     Ads                    2
# 162328   China   17         0     Seo                    1
# 158039   China   28         1     Seo                    5
# ...Done.
# [[-1.3990984  -1.15935344  1.          0.          0.          0.
#    0.          1.        ]
#  [ 0.29299544  0.03743241  1.          0.          0.          1.
#    1.          0.        ]
#  [ 2.46854467 -0.86015697  1.          0.          0.          1.
#    0.          0.        ]
#  [-1.64082609 -1.15935344  0.          0.          0.          0.
#    0.          1.        ]
#  [-0.31132378  0.03743241  1.          0.          0.          0.
#    0.          1.        ]]
#
# Performing preprocessings on test set...
#        country  age  new_user  source  total_pages_visited
# 138303      UK   34         1     Ads                    1
# 133130      UK   32         0     Ads                    5
# 245758      US   44         1     Ads                    1
# 185267      US   35         1  Direct                    1
# 177637      US   29         1  Direct                    3
# ...Done.
# [[ 0.41385929 -1.15935344  1.          0.          1.          0.
#    0.          0.        ]
#  [ 0.1721316   0.03743241  0.          0.          1.          0.
#    0.          0.        ]
#  [ 1.62249775 -1.15935344  1.          0.          0.          1.
#    0.          0.        ]
#  [ 0.53472314 -1.15935344  1.          0.          0.          1.
#    1.          0.        ]
#  [-0.19045994 -0.56096051  1.          0.          0.          1.
#    1.          0.        ]]

# %% [markdown]
# ## Performance assessment
# - f1_score, cross_val_score, confusion matrices, Feature Importance and Classification report

# %%
def evaluate_performance(model):
  Y_train_pred = model.predict(X_train)
  Y_test_pred = model.predict(X_test)

  # Here, the f1-score will be used to assess the performances on the leaderboard
  print(model.__class__.__name__)
  print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
  print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))
  print()
  
  scores = cross_val_score(model, X_train, Y_train, cv=5, scoring='f1')
  print('The cross-validated f1 score is : ', scores.mean())
  print('The standard deviation is : ', scores.std())
  print('is this model overfitting ? ', f1_score(Y_test, Y_test_pred) - f1_score(Y_train, Y_train_pred) > scores.std())

  # Visualize confusion matrices
  _, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
  axes[0].set(title="Confusion Matrix on Train set") # Set a title that we will add into ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_estimator(model, X_train, Y_train, ax=axes[0]) # ConfusionMatrixDisplay from sklearn

  axes[1].set(title="Confusion Matrix on Test set") # Set a title that we will add into ConfusionMatrixDisplay
  ConfusionMatrixDisplay.from_estimator(model, X_test, Y_test, ax=axes[1]) # ConfusionMatrixDisplay from sklearn
  plt.show()

  # Feature Importance
  # numeric_features +  encoded categorical column names
  columns = np.append(numeric_features, preprocessor.transformers_[1][1]['encoder'].get_feature_names_out(categorical_features))
  try:
    coefs = pd.DataFrame(index=columns, data=model.coef_.transpose(), columns=['coefficients'] )
    # Compute abs() and sort values
    feature_importance = abs(coefs).sort_values(by = 'coefficients')
    # Plot coefficients
    fig = px.bar(feature_importance, orientation = 'h', title='Feature Importance')
    fig.update_layout(showlegend = False, 
                      margin = {'l': 120} # to avoid cropping of column names
                      )
    fig.show()
  except:
    pass

  # Classification report
  print('classification_report on Train set')
  print(classification_report(Y_train,Y_train_pred))
  print('---')
  print('classification_report on Test set')
  print(classification_report(Y_test,Y_test_pred))

# %%
def get_f1_score(model):
  Y_train_pred = model.predict(X_train)
  Y_test_pred = model.predict(X_test)

  # Here, the f1-score will be used to assess the performances on the leaderboard
  print(model.__class__.__name__)
  print("f1-score on train set : ", f1_score(Y_train, Y_train_pred))
  print("f1-score on test set : ", f1_score(Y_test, Y_test_pred))

# %% [markdown]
# ## Model

# %% [markdown]
# #### **Boosting**

# %% [markdown]
# ##### LGBM (with hyperparameter optimization)

# %%
# Perform grid search
print("Grid search...")
lgbm = LGBMClassifier()

# Grid of values to be tested
params = {
    # on commence grand
    # 'max_depth': [10, 100, 1000],
    # 'min_child_weight': [2, 20, 200],
    # 'n_estimators': [1, 10, 100]

    # on a réduit à
    'max_depth': [5,6,7],
    'min_child_weight': [17, 18, 19],
    'n_estimators': [59, 60, 61]
}
print(params)
lgbm_opt = GridSearchCV(lgbm, param_grid = params, scoring='f1', cv = 3, verbose = 3) # cv : the number of folds to be used for CV
lgbm_opt.fit(X_train, Y_train)
print("...Done.")
print()
get_f1_score(lgbm_opt)
# Out:
# Grid search...
# {'max_depth': [5, 6, 7], 'min_child_weight': [17, 18, 19], 'n_estimators': [59, 60, 61]}
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 1/3] END max_depth=5, min_child_weight=17, n_estimators=59;, score=0.756 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=17, n_estimators=59;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=17, n_estimators=59;, score=0.775 total time=   0.3s
# [CV 1/3] END max_depth=5, min_child_weight=17, n_estimators=60;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=17, n_estimators=60;, score=0.764 total time=   0.4s
# [CV 3/3] END max_depth=5, min_child_weight=17, n_estimators=60;, score=0.776 total time=   0.6s
# [CV 1/3] END max_depth=5, min_child_weight=17, n_estimators=61;, score=0.757 total time=   0.4s
# [CV 2/3] END max_depth=5, min_child_weight=17, n_estimators=61;, score=0.765 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=17, n_estimators=61;, score=0.775 total time=   0.5s
# [CV 1/3] END max_depth=5, min_child_weight=18, n_estimators=59;, score=0.755 total time=   0.5s
# [CV 2/3] END max_depth=5, min_child_weight=18, n_estimators=59;, score=0.764 total time=   0.4s
# [CV 3/3] END max_depth=5, min_child_weight=18, n_estimators=59;, score=0.773 total time=   0.3s
# [CV 1/3] END max_depth=5, min_child_weight=18, n_estimators=60;, score=0.756 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=18, n_estimators=60;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=18, n_estimators=60;, score=0.773 total time=   0.3s
# [CV 1/3] END max_depth=5, min_child_weight=18, n_estimators=61;, score=0.756 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=18, n_estimators=61;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=18, n_estimators=61;, score=0.773 total time=   0.3s
# [CV 1/3] END max_depth=5, min_child_weight=19, n_estimators=59;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=19, n_estimators=59;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=19, n_estimators=59;, score=0.771 total time=   0.3s
# [CV 1/3] END max_depth=5, min_child_weight=19, n_estimators=60;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=19, n_estimators=60;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=19, n_estimators=60;, score=0.772 total time=   0.3s
# [CV 1/3] END max_depth=5, min_child_weight=19, n_estimators=61;, score=0.755 total time=   0.3s
# [CV 2/3] END max_depth=5, min_child_weight=19, n_estimators=61;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=5, min_child_weight=19, n_estimators=61;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=17, n_estimators=59;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=17, n_estimators=59;, score=0.765 total time=   0.3s
# [CV 3/3] END max_depth=6, min_child_weight=17, n_estimators=59;, score=0.773 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=17, n_estimators=60;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=17, n_estimators=60;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=6, min_child_weight=17, n_estimators=60;, score=0.773 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=17, n_estimators=61;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=17, n_estimators=61;, score=0.766 total time=   0.4s
# [CV 3/3] END max_depth=6, min_child_weight=17, n_estimators=61;, score=0.773 total time=   0.5s
# [CV 1/3] END max_depth=6, min_child_weight=18, n_estimators=59;, score=0.758 total time=   0.4s
# [CV 2/3] END max_depth=6, min_child_weight=18, n_estimators=59;, score=0.766 total time=   0.4s
# [CV 3/3] END max_depth=6, min_child_weight=18, n_estimators=59;, score=0.773 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=18, n_estimators=60;, score=0.758 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=18, n_estimators=60;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=6, min_child_weight=18, n_estimators=60;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=18, n_estimators=61;, score=0.758 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=18, n_estimators=61;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=6, min_child_weight=18, n_estimators=61;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=19, n_estimators=59;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=19, n_estimators=59;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=6, min_child_weight=19, n_estimators=59;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=19, n_estimators=60;, score=0.756 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=19, n_estimators=60;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=6, min_child_weight=19, n_estimators=60;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=6, min_child_weight=19, n_estimators=61;, score=0.756 total time=   0.3s
# [CV 2/3] END max_depth=6, min_child_weight=19, n_estimators=61;, score=0.764 total time=   0.4s
# [CV 3/3] END max_depth=6, min_child_weight=19, n_estimators=61;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=17, n_estimators=59;, score=0.755 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=17, n_estimators=59;, score=0.765 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=17, n_estimators=59;, score=0.776 total time=   0.6s
# [CV 1/3] END max_depth=7, min_child_weight=17, n_estimators=60;, score=0.755 total time=   0.4s
# [CV 2/3] END max_depth=7, min_child_weight=17, n_estimators=60;, score=0.765 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=17, n_estimators=60;, score=0.776 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=17, n_estimators=61;, score=0.755 total time=   0.4s
# [CV 2/3] END max_depth=7, min_child_weight=17, n_estimators=61;, score=0.766 total time=   0.4s
# [CV 3/3] END max_depth=7, min_child_weight=17, n_estimators=61;, score=0.776 total time=   0.4s
# [CV 1/3] END max_depth=7, min_child_weight=18, n_estimators=59;, score=0.758 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=18, n_estimators=59;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=18, n_estimators=59;, score=0.775 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=18, n_estimators=60;, score=0.758 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=18, n_estimators=60;, score=0.765 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=18, n_estimators=60;, score=0.775 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=18, n_estimators=61;, score=0.758 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=18, n_estimators=61;, score=0.764 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=18, n_estimators=61;, score=0.775 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=19, n_estimators=59;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=19, n_estimators=59;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=19, n_estimators=59;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=19, n_estimators=60;, score=0.757 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=19, n_estimators=60;, score=0.766 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=19, n_estimators=60;, score=0.774 total time=   0.3s
# [CV 1/3] END max_depth=7, min_child_weight=19, n_estimators=61;, score=0.758 total time=   0.3s
# [CV 2/3] END max_depth=7, min_child_weight=19, n_estimators=61;, score=0.767 total time=   0.3s
# [CV 3/3] END max_depth=7, min_child_weight=19, n_estimators=61;, score=0.774 total time=   0.3s
# ...Done.
# Best hyperparameters :  {'max_depth': 6, 'min_child_weight': 18, 'n_estimators': 60}
# Best validation accuracy :  0.7660637691223119
#
# GridSearchCV
# f1-score on train set :  0.770478387024775
# f1-score on test set :  0.755741127348643

# %%
print("Best hyperparameters : ", lgbm_opt.best_params_)
print("Best validation accuracy : ", lgbm_opt.best_score_)
# Out:
# Best hyperparameters :  {'max_depth': 6, 'min_child_weight': 18, 'n_estimators': 60}
# Best validation accuracy :  0.7660637691223119

# %%
evaluate_performance(lgbm_opt.best_estimator_)
# Out:
# LGBMClassifier
# f1-score on train set :  0.770478387024775
# f1-score on test set :  0.755741127348643
#
# The cross-validated f1 score is :  0.76539160111717
# The standard deviation is :  0.006895744378426573
# is this model overfitting ?  False
# classification_report on Train set
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99    220320
#            1       0.85      0.71      0.77      7344
#
#     accuracy                           0.99    227664
#    macro avg       0.92      0.85      0.88    227664
# weighted avg       0.99      0.99      0.99    227664
#
# ---
# classification_report on Test set
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     55080
#            1       0.84      0.69      0.76      1836
#
#     accuracy                           0.99     56916
#    macro avg       0.91      0.84      0.87     56916
# weighted avg       0.98      0.99      0.98     56916

# %% [markdown]
# ## Submission

# %%
def retrain_and_submit(model, version=1):
  print(model)
  # Concatenate our train and test set to train your best classifier on all data with labels
  X = np.append(X_train,X_test,axis=0)
  Y = np.append(Y_train,Y_test)

  model.fit(X,Y)

  # Read data without labels
  data_without_labels = pd.read_csv('data/conversion_data_test.csv')
  print('Prediction set (without labels) :', data_without_labels.shape)

  # apply the preprocessing
  X_without_labels = preprocessor.transform(data_without_labels)
  data = {
    'converted': model.predict(X_without_labels)
  }

  Y_predictions = pd.DataFrame(columns=['converted'],data=data)
  Y_predictions.to_csv(f'submissions/conversion_data_test_predictions_Alexon_V{version}.csv', index=False)
  print('Done ....')

# %%
retrain_and_submit(lgbm_opt.best_estimator_, version=19)
# Out:
# LGBMClassifier(max_depth=6, min_child_weight=18, n_estimators=60)
# Prediction set (without labels) : (31620, 5)
# Done ....

# %%
simple_lgbm = LGBMClassifier()
retrain_and_submit(simple_lgbm, version=23)
# Out:
# LGBMClassifier()
# Prediction set (without labels) : (31620, 5)
# Done ....

# %%
pickle.dump(simple_lgbm, open('models/lgbm_v_23', 'wb'))
